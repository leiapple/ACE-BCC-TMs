# %%
from ase.io import read, write
import os
import shutil

def write_poscar_with_selective_dynamics(filename, atoms, selective_dynamics):
    """
    Write a POSCAR file with Selective Dynamics flags.
    
    Args:
        filename (str): Name of the output POSCAR file.
        atoms (ase.Atoms): The atomic structure.
        selective_dynamics (list): List of [X, Y, Z] flags for each atom.
    """
    with open(filename, 'w') as f:
        # Write the header
        f.write('System Name\n')
        f.write('1.10343677\n')
        
        # Write the cell vectors
        for vector in atoms.cell:
            f.write(f'{vector[0]:20.16f} {vector[1]:20.16f} {vector[2]:20.16f}\n')
        
        # Write the atomic symbols and counts
        symbols = atoms.get_chemical_symbols()
        unique_symbols = sorted(set(symbols), key=symbols.index)
        counts = [symbols.count(symbol) for symbol in unique_symbols]
        f.write(' '.join(unique_symbols) + '\n')
        f.write(' '.join(map(str, counts)) + '\n')
        
        # Write Selective Dynamics line
        f.write('Selective dynamics\n')
        
        # Write Cartesian or Direct coordinates
        f.write('Cartesian\n')
        
        # Write atomic positions and Selective Dynamics flags
        for i, atom in enumerate(atoms):
            pos = atom.position
            flags = selective_dynamics[i]
            f.write(f'{pos[0]:20.16f} {pos[1]:20.16f} {pos[2]:20.16f} ')
            f.write(f'{"T" if flags[0] else "F"} {"T" if flags[1] else "F"} {"T" if flags[2] else "F"}\n')


# SLURM job script template
slurm_template = """#!/bin/bash
#SBATCH --job-name=Nb_{i}_{j}
#SBATCH --output=slurm_{i}_{j}.out
#SBATCH --error=slurm_{i}_{j}.err
#SBATCH --nodes=2
#SBATCH --ntasks-per-node=10
#SBATCH --cpus-per-task=1
#SBATCH --time=8:00:00
#SBATCH --partition=regularshort
#SBATCH --mem-per-cpu=8G

# Load necessary modules (if required)
module load VASP

# Run the calculation
srun vasp_std
"""

# List of source files
source_files = [
    '/scratch/p301616/VASP_DFT_bcc_DB/niobium_NewGammaSurf_110/INPUTS_temp/INCAR',
    '/scratch/p301616/VASP_DFT_bcc_DB/niobium_NewGammaSurf_110/INPUTS_temp/POTCAR'
]

###########################M
# MAIN CODE
############################

# Read the XYZ file

ny = 20
nz = 12
perf_110 = read('/scratch/p301616/VASP_DFT_bcc_DB/niobium_NewGammaSurf_112/112_plane.xyz')

# Loop through the first 1000 items in primitive_xyz
for i in range(ny):
    for j in range(nz):
        direc = 'Nb_gammaSurf_' + str(i) + '_' + str(j)

        os.makedirs(direc, exist_ok=True)
        os.chdir(direc)
        primitive_xyz = perf_110.copy()
        # Define Selective Dynamics flags (F T T for all atoms)
        selective_dynamics = [[True, False, False] for _ in range(len(primitive_xyz))]
        # add the displacement
        primitive_xyz.cell[0][1] += i * primitive_xyz.cell[1][1]/ny
        primitive_xyz.cell[0][2] += j * primitive_xyz.cell[2][2]/nz

        # Write the POSCAR file with Selective Dynamics
        write_poscar_with_selective_dynamics('POSCAR', primitive_xyz, selective_dynamics)
        
        # Get the current directory
        current_directory = os.getcwd()
        # copy INCAR and POTCAR files
        for source_file in source_files:
            shutil.copy(source_file, current_directory)

        # Write the SLURM job script
        with open('job_{}_{}.sh'.format(i,j), 'w') as f:
            f.write(slurm_template.format(i=i,j=j))

        # Submit the SLURM job
        os.system('sbatch job_{}_{}.sh'.format(i,j))

        print('job {} + {} submitted!'.format(i,j))
        os.chdir("../")
# Out:
# job 0 + 0 submitted!
# Submitted batch job 17962675
# job 0 + 1 submitted!
# Submitted batch job 17962676
# Submitted batch job 17962677
# job 0 + 2 submitted!
# Submitted batch job 17962678
# job 0 + 3 submitted!
# Submitted batch job 17962679
# job 0 + 4 submitted!
# Submitted batch job 17962680
# job 0 + 5 submitted!
# Submitted batch job 17962681
# job 0 + 6 submitted!
# job 0 + 7 submitted!
# Submitted batch job 17962682
# Submitted batch job 17962683
# job 0 + 8 submitted!
# Submitted batch job 17962684
# job 0 + 9 submitted!
# Submitted batch job 17962685
# job 0 + 10 submitted!
# Submitted batch job 17962686
# job 0 + 11 submitted!
# Submitted batch job 17962687
# job 1 + 0 submitted!
# Submitted batch job 17962688
# job 1 + 1 submitted!
# Submitted batch job 17962689
# job 1 + 2 submitted!
# Submitted batch job 17962690
# job 1 + 3 submitted!
# Submitted batch job 17962691
# job 1 + 4 submitted!
# job 1 + 5 submitted!
# Submitted batch job 17962692
# Submitted batch job 17962693
# job 1 + 6 submitted!
# job 1 + 7 submitted!
# Submitted batch job 17962694
# job 1 + 8 submitted!
# Submitted batch job 17962695
# Submitted batch job 17962696
# job 1 + 9 submitted!
# Submitted batch job 17962697
# job 1 + 10 submitted!
# Submitted batch job 17962698
# job 1 + 11 submitted!
# Submitted batch job 17962699
# job 2 + 0 submitted!
# job 2 + 1 submitted!
# Submitted batch job 17962700
# Submitted batch job 17962701
# job 2 + 2 submitted!
# Submitted batch job 17962702
# job 2 + 3 submitted!
# Submitted batch job 17962703
# job 2 + 4 submitted!
# Submitted batch job 17962704
# job 2 + 5 submitted!
# Submitted batch job 17962705
# job 2 + 6 submitted!
# Submitted batch job 17962706
# job 2 + 7 submitted!
# Submitted batch job 17962707
# job 2 + 8 submitted!
# Submitted batch job 17962708
# job 2 + 9 submitted!
# Submitted batch job 17962709
# job 2 + 10 submitted!
# Submitted batch job 17962710
# job 2 + 11 submitted!
# Submitted batch job 17962711
# job 3 + 0 submitted!
# Submitted batch job 17962712
# job 3 + 1 submitted!
# Submitted batch job 17962713
# job 3 + 2 submitted!
# Submitted batch job 17962714
# job 3 + 3 submitted!
# Submitted batch job 17962715
# job 3 + 4 submitted!
# Submitted batch job 17962716
# job 3 + 5 submitted!
# Submitted batch job 17962717
# job 3 + 6 submitted!
# Submitted batch job 17962718
# job 3 + 7 submitted!
# Submitted batch job 17962719
# job 3 + 8 submitted!
# Submitted batch job 17962720
# job 3 + 9 submitted!
# Submitted batch job 17962721
# job 3 + 10 submitted!
# Submitted batch job 17962722
# job 3 + 11 submitted!
# Submitted batch job 17962723
# job 4 + 0 submitted!
# Submitted batch job 17962724
# job 4 + 1 submitted!
# Submitted batch job 17962725
# job 4 + 2 submitted!
# Submitted batch job 17962726
# job 4 + 3 submitted!
# Submitted batch job 17962727
# job 4 + 4 submitted!
# Submitted batch job 17962728
# job 4 + 5 submitted!
# Submitted batch job 17962729
# job 4 + 6 submitted!
# Submitted batch job 17962730
# job 4 + 7 submitted!
# Submitted batch job 17962731
# job 4 + 8 submitted!
# Submitted batch job 17962732
# job 4 + 9 submitted!
# Submitted batch job 17962733
# job 4 + 10 submitted!
# Submitted batch job 17962734
# job 4 + 11 submitted!
# Submitted batch job 17962735
# job 5 + 0 submitted!
# Submitted batch job 17962736
# job 5 + 1 submitted!
# Submitted batch job 17962737
# job 5 + 2 submitted!
# Submitted batch job 17962738
# job 5 + 3 submitted!
# Submitted batch job 17962739
# job 5 + 4 submitted!
# Submitted batch job 17962740
# job 5 + 5 submitted!
# Submitted batch job 17962741
# job 5 + 6 submitted!
# Submitted batch job 17962742
# job 5 + 7 submitted!
# Submitted batch job 17962743
# job 5 + 8 submitted!
# Submitted batch job 17962744
# job 5 + 9 submitted!
# Submitted batch job 17962745
# job 5 + 10 submitted!
# Submitted batch job 17962746
# job 5 + 11 submitted!
# Submitted batch job 17962747
# job 6 + 0 submitted!
# job 6 + 1 submitted!
# Submitted batch job 17962748
# Submitted batch job 17962749
# job 6 + 2 submitted!
# Submitted batch job 17962750
# job 6 + 3 submitted!
# Submitted batch job 17962751
# job 6 + 4 submitted!
# Submitted batch job 17962752
# job 6 + 5 submitted!
# Submitted batch job 17962753
# job 6 + 6 submitted!
# job 6 + 7 submitted!
# Submitted batch job 17962754
# Submitted batch job 17962755
# job 6 + 8 submitted!
# Submitted batch job 17962756
# job 6 + 9 submitted!
# Submitted batch job 17962757
# job 6 + 10 submitted!
# Submitted batch job 17962758
# job 6 + 11 submitted!
# Submitted batch job 17962759
# job 7 + 0 submitted!
# job 7 + 1 submitted!
# Submitted batch job 17962760
# job 7 + 2 submitted!
# Submitted batch job 17962761
# job 7 + 3 submitted!
# Submitted batch job 17962762
# Submitted batch job 17962763
# job 7 + 4 submitted!
# job 7 + 5 submitted!
# Submitted batch job 17962764
# job 7 + 6 submitted!
# Submitted batch job 17962765
# job 7 + 7 submitted!
# Submitted batch job 17962766
# job 7 + 8 submitted!
# Submitted batch job 17962767
# Submitted batch job 17962768
# job 7 + 9 submitted!
# Submitted batch job 17962769
# job 7 + 10 submitted!
# Submitted batch job 17962770
# job 7 + 11 submitted!
# Submitted batch job 17962771
# job 8 + 0 submitted!
# Submitted batch job 17962772
# job 8 + 1 submitted!
# Submitted batch job 17962773
# job 8 + 2 submitted!
# Submitted batch job 17962774
# job 8 + 3 submitted!
# Submitted batch job 17962775
# job 8 + 4 submitted!
# Submitted batch job 17962776
# job 8 + 5 submitted!
# job 8 + 6 submitted!
# Submitted batch job 17962777
# Submitted batch job 17962778
# job 8 + 7 submitted!
# Submitted batch job 17962779
# job 8 + 8 submitted!
# Submitted batch job 17962780
# job 8 + 9 submitted!
# Submitted batch job 17962781
# job 8 + 10 submitted!
# Submitted batch job 17962782
# job 8 + 11 submitted!
# Submitted batch job 17962783
# job 9 + 0 submitted!
# Submitted batch job 17962784
# job 9 + 1 submitted!
# Submitted batch job 17962785
# job 9 + 2 submitted!
# Submitted batch job 17962786
# job 9 + 3 submitted!
# job 9 + 4 submitted!
# Submitted batch job 17962787
# Submitted batch job 17962788
# job 9 + 5 submitted!
# Submitted batch job 17962789
# job 9 + 6 submitted!
# Submitted batch job 17962790
# job 9 + 7 submitted!
# Submitted batch job 17962791
# job 9 + 8 submitted!
# Submitted batch job 17962792
# job 9 + 9 submitted!
# Submitted batch job 17962793
# job 9 + 10 submitted!
# Submitted batch job 17962794
# job 9 + 11 submitted!
# Submitted batch job 17962795
# job 10 + 0 submitted!
# Submitted batch job 17962796
# job 10 + 1 submitted!
# Submitted batch job 17962797
# job 10 + 2 submitted!
# Submitted batch job 17962798
# job 10 + 3 submitted!
# Submitted batch job 17962799
# job 10 + 4 submitted!
# Submitted batch job 17962800
# job 10 + 5 submitted!
# Submitted batch job 17962801
# job 10 + 6 submitted!
# Submitted batch job 17962802
# job 10 + 7 submitted!
# Submitted batch job 17962803
# job 10 + 8 submitted!
# Submitted batch job 17962804
# job 10 + 9 submitted!
# Submitted batch job 17962805
# job 10 + 10 submitted!
# Submitted batch job 17962806
# job 10 + 11 submitted!
# Submitted batch job 17962807
# job 11 + 0 submitted!
# Submitted batch job 17962808
# job 11 + 1 submitted!
# Submitted batch job 17962809
# job 11 + 2 submitted!
# Submitted batch job 17962810
# job 11 + 3 submitted!
# Submitted batch job 17962811
# job 11 + 4 submitted!
# Submitted batch job 17962812
# job 11 + 5 submitted!
# Submitted batch job 17962813
# job 11 + 6 submitted!
# Submitted batch job 17962814
# job 11 + 7 submitted!
# Submitted batch job 17962815
# job 11 + 8 submitted!
# Submitted batch job 17962816
# job 11 + 9 submitted!
# Submitted batch job 17962817
# job 11 + 10 submitted!
# Submitted batch job 17962818
# job 11 + 11 submitted!
# Submitted batch job 17962819
# job 12 + 0 submitted!
# Submitted batch job 17962820
# job 12 + 1 submitted!
# Submitted batch job 17962821
# job 12 + 2 submitted!
# Submitted batch job 17962822
# job 12 + 3 submitted!
# Submitted batch job 17962823
# job 12 + 4 submitted!
# Submitted batch job 17962824
# job 12 + 5 submitted!
# Submitted batch job 17962825
# job 12 + 6 submitted!
# Submitted batch job 17962826
# job 12 + 7 submitted!
# Submitted batch job 17962827
# job 12 + 8 submitted!
# Submitted batch job 17962828
# job 12 + 9 submitted!
# Submitted batch job 17962829
# job 12 + 10 submitted!
# Submitted batch job 17962830
# job 12 + 11 submitted!
# Submitted batch job 17962831
# job 13 + 0 submitted!
# Submitted batch job 17962832
# job 13 + 1 submitted!
# job 13 + 2 submitted!
# Submitted batch job 17962833
# Submitted batch job 17962834
# job 13 + 3 submitted!
# Submitted batch job 17962835
# job 13 + 4 submitted!
# Submitted batch job 17962836
# job 13 + 5 submitted!
# Submitted batch job 17962837
# job 13 + 6 submitted!
# Submitted batch job 17962838
# job 13 + 7 submitted!
# Submitted batch job 17962839
# job 13 + 8 submitted!
# Submitted batch job 17962841
# job 13 + 9 submitted!
# Submitted batch job 17962842
# job 13 + 10 submitted!
# Submitted batch job 17962843
# job 13 + 11 submitted!
# Submitted batch job 17962844
# job 14 + 0 submitted!
# Submitted batch job 17962845
# job 14 + 1 submitted!
# Submitted batch job 17962846
# job 14 + 2 submitted!
# Submitted batch job 17962847
# job 14 + 3 submitted!
# Submitted batch job 17962848
# job 14 + 4 submitted!
# Submitted batch job 17962849
# job 14 + 5 submitted!
# Submitted batch job 17962850
# job 14 + 6 submitted!
# Submitted batch job 17962851
# job 14 + 7 submitted!
# job 14 + 8 submitted!
# Submitted batch job 17962852
# Submitted batch job 17962853
# job 14 + 9 submitted!
# Submitted batch job 17962854
# job 14 + 10 submitted!
# Submitted batch job 17962855
# job 14 + 11 submitted!
# Submitted batch job 17962856
# job 15 + 0 submitted!
# Submitted batch job 17962857
# job 15 + 1 submitted!
# Submitted batch job 17962858
# job 15 + 2 submitted!
# Submitted batch job 17962859
# job 15 + 3 submitted!
# Submitted batch job 17962860
# job 15 + 4 submitted!
# Submitted batch job 17962861
# job 15 + 5 submitted!
# Submitted batch job 17962862
# job 15 + 6 submitted!
# Submitted batch job 17962863
# job 15 + 7 submitted!
# Submitted batch job 17962864
# job 15 + 8 submitted!
# Submitted batch job 17962865
# job 15 + 9 submitted!
# Submitted batch job 17962866
# job 15 + 10 submitted!
# Submitted batch job 17962867
# job 15 + 11 submitted!
# Submitted batch job 17962868
# job 16 + 0 submitted!
# Submitted batch job 17962869
# job 16 + 1 submitted!
# Submitted batch job 17962870
# job 16 + 2 submitted!
# Submitted batch job 17962871
# job 16 + 3 submitted!
# Submitted batch job 17962872
# job 16 + 4 submitted!
# Submitted batch job 17962873
# job 16 + 5 submitted!
# Submitted batch job 17962874
# job 16 + 6 submitted!
# Submitted batch job 17962875
# job 16 + 7 submitted!
# Submitted batch job 17962876
# job 16 + 8 submitted!
# Submitted batch job 17962877
# job 16 + 9 submitted!
# Submitted batch job 17962878
# job 16 + 10 submitted!
# Submitted batch job 17962879
# job 16 + 11 submitted!
# Submitted batch job 17962880
# job 17 + 0 submitted!
# Submitted batch job 17962881
# job 17 + 1 submitted!
# Submitted batch job 17962882
# job 17 + 2 submitted!
# Submitted batch job 17962883
# job 17 + 3 submitted!
# Submitted batch job 17962884
# job 17 + 4 submitted!
# Submitted batch job 17962886
# job 17 + 5 submitted!
# Submitted batch job 17962887
# job 17 + 6 submitted!
# Submitted batch job 17962888
# job 17 + 7 submitted!
# Submitted batch job 17962889
# job 17 + 8 submitted!
# Submitted batch job 17962890
# job 17 + 9 submitted!
# Submitted batch job 17962891
# job 17 + 10 submitted!
# Submitted batch job 17962892
# job 17 + 11 submitted!
# Submitted batch job 17962893
# job 18 + 0 submitted!
# Submitted batch job 17962894
# job 18 + 1 submitted!
# Submitted batch job 17962895
# job 18 + 2 submitted!
# Submitted batch job 17962896
# job 18 + 3 submitted!
# job 18 + 4 submitted!
# Submitted batch job 17962897
# Submitted batch job 17962898
# job 18 + 5 submitted!
# Submitted batch job 17962899
# job 18 + 6 submitted!
# Submitted batch job 17962900
# job 18 + 7 submitted!
# Submitted batch job 17962901
# job 18 + 8 submitted!
# Submitted batch job 17962902
# job 18 + 9 submitted!
# Submitted batch job 17962903
# job 18 + 10 submitted!
# Submitted batch job 17962904
# job 18 + 11 submitted!
# Submitted batch job 17962905
# job 19 + 0 submitted!
# Submitted batch job 17962906
# job 19 + 1 submitted!
# Submitted batch job 17962907
# job 19 + 2 submitted!
# Submitted batch job 17962908
# job 19 + 3 submitted!
# Submitted batch job 17962909
# job 19 + 4 submitted!
# Submitted batch job 17962910
# job 19 + 5 submitted!
# Submitted batch job 17962911
# job 19 + 6 submitted!
# Submitted batch job 17962912
# job 19 + 7 submitted!
# Submitted batch job 17962913
# job 19 + 8 submitted!
# Submitted batch job 17962914
# job 19 + 9 submitted!
# job 19 + 10 submitted!
# Submitted batch job 17962915
# Submitted batch job 17962916
# job 19 + 11 submitted!
